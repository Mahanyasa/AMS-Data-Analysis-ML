# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahanyasa/AMS-Data-Analysis-ML/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Attendance Management System - Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('TD Attendance - Sheet1.csv')
data.head()
# Out:
#              Name Domain             Logged Time
# 0       Krishna V    IOT  6:10 PM at February 23
# 1  Paavan Agrawal    Web  6:14 PM at February 23
# 2  Deepak Kailash    Web  6:15 PM at February 23
# 3    Harsh Aswani    Web  6:25 PM at February 23
# 4      Anuj Singh    Web  6:27 PM at February 23

# %%
data.shape
# Out:
# (117, 3)

# %%
print("\nNumber of participants/attendees : ",data['Name'].nunique())
print("\nNames of the participants : ")
print(data['Name'].unique())
# Out:
# Number of participants/attendees :  53
#
# Names of the participants :
# ['Krishna V' 'Paavan Agrawal' 'Deepak Kailash' 'Harsh Aswani' 'Anuj Singh'
#  'Muskan' 'Jigyasa Raj' 'Mahisha S' 'Diya Rastogi' 'Narra Sathwika'
#  'Aayushi Agarwal' 'Lavanya Dey' 'Shitanshu Priyadarshi' 'Priyanshi Pusan'
#  'Vibhuti Joshi' 'Siya Chugh' 'Sourav Sankar' 'Khushi Upadhyay'
#  'Rishabh Motiani' 'Chiya Tiwari' 'Ekansh Motiani'
#  'Chidambaram Arunachalam' 'Ritveek Rana' 'Shrinjoyee Chatterjee'
#  'S Surya Prakash' 'Mahanyaasa Keesara' 'Gagandeep C' 'D Vamsidar'
#  'Matta Manoghna Venkata Sai Rithvik' 'Kunal Keshan S' 'Yash Tripati'
#  'Divija Agarwal' 'N Subramanian' 'Himanshu Thakur' 'Debajyoti Mandal'
#  'Kabir Gupta' 'Nitesh Dilip Gupta' 'Koushik Jhade' 'Ritam Biswas'
#  'Mahanyasa Keesara' 'Abheelash Mishra' 'Tatinani Sai Teja' 'Prakash Raj'
#  'Priyanshu Raj' 'Rohit Ghosh' 'Aruliya Asokan' 'Kaustubh Shatdhar'
#  'Shinjan Patra' 'Muskan Kumari' 'Mathangy K' 'Rohan Kumar'
# ...

# %%
print("Number of domains : ",data['Domain'].nunique())
data['Domain'].unique()
# Out:
# Number of domains :  8
# array(['IOT', 'Web', 'Organizer', 'Content', 'Graphic', 'Event', 'ML',
#        'Admin'], dtype=object)

# %%
dataset = data['Domain'].value_counts()
dataset.to_csv('Domains.csv')

# %%
domain = pd.read_csv('Domains.csv')
domain.head()
# Out:
#   Unnamed: 0  Domain
# 0        Web      41
# 1      Event      23
# 2         ML      14
# 3        IOT      13
# 4    Content       9

# %%
number = list(data['Domain'].value_counts())

# %%
number
# Out:
# [41, 23, 14, 13, 9, 7, 6, 4]

# %%
data.groupby('Domain').size().plot(kind='pie',subplots=True)
plt.title('Strength of attendees')
# Out:
# Text(0.5, 1.0, 'Strength of attendees')

# %%
x_axis = domain['Domain']
y_axis = domain['Count']
plt.title('Domain vs Count(Participants)')
plt.xlabel('Domain')
plt.ylabel('Count')
plt.bar(x_axis,y_axis)
plt.xticks(rotation=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print('ML DOMAIN\'S compiled data')
data[data['Domain']=='ML']
data[data['Domain']=='ML'].groupby('Name').size().plot(kind='pie',subplots=True)
plt.title('Strength of attendees')
# Out:
# ML DOMAIN'S compiled data
# Text(0.5, 1.0, 'Strength of attendees')

# %%
print('WEB DOMAIN\'S compiled data')
data[data['Domain']=='Web']
data[data['Domain']=='Web'].groupby('Name').size().plot(kind='pie',subplots=True)
plt.title('Strength of attendees')
# Out:
# WEB DOMAIN'S compiled data
# Text(0.5, 1.0, 'Strength of attendees')

# %%
print('EVENT DOMAIN\'S compiled data')
data[data['Domain']=='Event']
data[data['Domain']=='Event'].groupby('Name').size().plot(kind='pie',subplots=True)
plt.title('Strength of attendees')
# Out:
# EVENT DOMAIN'S compiled data
# Text(0.5, 1.0, 'Strength of attendees')

# %%
print('IOT DOMAIN\'S compiled data')
data[data['Domain']=='IOT']
data[data['Domain']=='IOT'].groupby('Name').size().plot(kind='pie',subplots=True)
plt.title('Strength of attendees')
# Out:
# IOT DOMAIN'S compiled data
# Text(0.5, 1.0, 'Strength of attendees')

# %%
print('CONTENT DOMAIN\'S compiled data')
data[data['Domain']=='Content']
data[data['Domain']=='Content'].groupby('Name').size().plot(kind='pie',subplots=True)
plt.title('Strength of attendees')
# Out:
# CONTENT DOMAIN'S compiled data
# Text(0.5, 1.0, 'Strength of attendees')

# %%
print('Graphic DOMAIN\'S compiled data')
data[data['Domain']=='Graphic']
data[data['Domain']=='Graphic'].groupby('Name').size().plot(kind='pie',subplots=True)
plt.title('Strength of attendees')
# Out:
# Graphic DOMAIN'S compiled data
# Text(0.5, 1.0, 'Strength of attendees')

# %%
print('ORGANIZER\'S compiled data')
data[data['Domain']=='Organizer']
data[data['Domain']=='Organizer'].groupby('Name').size().plot(kind='pie',subplots=True)
plt.title('Strength of attendees')
# Out:
# ORGANIZER'S compiled data
# Text(0.5, 1.0, 'Strength of attendees')

# %%
print('ADMIN\'S compiled data')
data[data['Domain']=='Admin']
data[data['Domain']=='Admin'].groupby('Name').size().plot(kind='pie',subplots=True)
plt.title('Strength of attendees')
# Out:
# ADMIN'S compiled data
# Text(0.5, 1.0, 'Strength of attendees')
